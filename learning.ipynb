# %% [markdown]
# # 矩阵乘法

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## 矩阵乘法核心
# 矩阵乘法的计算规则是：
# $C$ 的每个元素 $c_{i,j}$ 由 $A$ 的第 $i$ 行与 $B$ 的第 $j$ 列的对应元素相乘后求和得到，即：
# $$
# C = A \times B
# $$
# 其具体计算公式如下：
# $$
# c_{i,j} = \sum_{k=1}^{k} a_{i,k} \cdot b_{k,j}
# $$
# 其中：
# - $i$ 表示 $A$ 的行索引，取值范围 $1 \leq i \leq 5$
# - $j$ 表示 $B$ 的列索引，取值范围 $1 \leq j \leq 3$
# - $k$ 表示求和的索引，对应矩阵 $A$ 的列索引和矩阵 $B$ 的行索引

# %%
np.random.seed(1314)
A = np.random.randint(0, 10, (5, 8))
B = np.random.randint(0, 10, (8, 3))
C = np.dot(A, B)
print("Matrix A:\n", A)
print("Matrix B:\n", B)
# Out:
# Matrix A:
#  [[5 5 8 7 5 2 0 4]
#  [7 0 9 7 6 2 3 2]
#  [6 3 7 1 3 9 1 5]
#  [0 5 8 1 5 0 9 6]
#  [0 1 0 6 9 5 7 8]]
# Matrix B:
#  [[9 7 0]
#  [9 6 6]
#  [4 1 6]
#  [6 2 4]
#  [6 2 7]
#  [4 6 2]
#  [8 8 8]
#  [6 3 3]]

# %%
## 可视化矩阵乘法
fig, axs = plt.subplots(1, 5, figsize=(8, 3))
plt.sca(axs[0])
ax = sns.heatmap(C, cmap='RdYlBu_r',
xticklabels = [], yticklabels = [],
cbar_kws={"orientation": "horizontal"})
ax.set_aspect("equal")
plt.title('C')
plt.sca(axs[1])
plt.title('=') # 绘制等号
plt.axis('off')
plt.sca(axs[2])
ax = sns.heatmap(A, cmap='RdYlBu_r',
xticklabels = [], yticklabels = [],
cbar_kws={"orientation": "horizontal"})
ax.set_aspect("equal")
plt.title('A')
plt.sca(axs[3])
plt.title('@') # 绘制乘号
plt.axis('off')
plt.sca(axs[4])
ax = sns.heatmap(B, cmap='RdYlBu_r',
xticklabels = [], yticklabels = [],
cbar_kws={"orientation": "horizontal"})
ax.set_aspect("equal")
plt.title('B')
# Out:
# Text(0.5, 1.0, 'B')

# %%
C
# Out:
# array([[142,  51],
#        [ 64,  18],
#        [145,  48]], dtype=int32)

# %%
a = np.array([[1, 2, 3]])
b = np.array([[4], [5], [6]])
c = np.dot(a, b)
c
# Out:
# array([[32]])

# %%
# a test of linear algebra

def matrix_multiplication(a,b):
    a_shape = a.shape
    b_shape = b.shape
    if a_shape[1] != b_shape[0]:
        raise ValueError("矩阵维度不匹配，无法相乘")
    result = np.zeros((a_shape[0], b_shape[1]))
    for i in range(a_shape[0]):
        for j in range(b_shape[1]):
            for k in range(a_shape[1]):
                result[i][j] += a[i][k] * b[k][j]
    return result

# %%
A = np.array([[1, 2, 3], [4, 5, 6]])
B = A.T
C = matrix_multiplication(A, B)
C
# Out:
# array([[14., 32.],
#        [32., 77.]])

# %% [markdown]
# ## 小测试

# %%
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])
C = matrix_multiplication(A, B)
D = matrix_multiplication(B, A)
C, D
# Out:
# (array([[19., 22.],
#         [43., 50.]]),
#  array([[23., 34.],
#         [31., 46.]]))

# %%
A = np.array([[1,2]])
B = np.array([[3],[4]])
print(A.shape, B.shape)
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C, D
# Out:
# (1, 2) (2, 1)
# (array([[11.]]),
#  array([[3., 6.],
#         [4., 8.]]))

# %%
# 单位矩阵满足矩阵乘法的交换律
A = np.eye(2)
B = np.array([[2,3],[4,5]])
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C, D
# Out:
# (array([[2., 3.],
#         [4., 5.]]),
#  array([[2., 3.],
#         [4., 5.]]))

# %%
# 如何解释
A = np.array([[1,2],[2,1]])
B = np.array([[3,4],[4,3]])
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C==D
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %%
# 
A = np.array([[1,1],[1,1]])
B = np.array([[2,2],[2,2]])
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C==D
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %% [markdown]
# ### 对角矩阵：主对角线以外的元素均为零的矩阵

# %%
# 对角矩阵满足交换律
A = np.array([[1,0],[0,2]])
B = np.array([[3,0],[0,4]])
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C==D
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %%
A = np.array([[np.cos(30), -np.sin(30)],[np.sin(30), np.cos(30)]])
B = np.array([[np.cos(60), -np.sin(60)],[np.sin(60), np.cos(60)]])
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C == D
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %%
# a test of linear algebra

def matrix_multiplication(a,b):
    a_shape = a.shape
    b_shape = b.shape
    if a_shape[1] != b_shape[0]:
        raise ValueError("矩阵维度不匹配，无法相乘")
    result = np.zeros((a_shape[0], b_shape[1]))
    for j in range(b_shape[1]):
            for i in range(a_shape[0]):
                for k in range(a_shape[1]):
                     result[i][j] += a[i][k] * b[k][j]
                     return result

# %%
A = np.array([[np.cos(30), -np.sin(30)],[np.sin(30), np.cos(30)]])
B = np.array([[np.cos(60), -np.sin(60)],[np.sin(60), np.cos(60)]])
C = matrix_multiplication(A,B)
D = matrix_multiplication(B,A)
C == D
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %% [markdown]
# # 矩阵乘法的几何视角
